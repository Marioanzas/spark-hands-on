# %% [markdown]
# <p align="center">
#    <img src="spark.png">
# </p>

# %% [markdown]
# # Spark Hands-on: Spark RDD
#
# In this notebook you will discover the **Spark** framework and its Python API (pySpark). We will cover the basic transformations and actions with **Spark Core** and its main component: the **Resilient Distributed Dataset** (RDD).
#
# In the next notebooks, we will go throught the **SQL API** that allow higher level queries that are optimized by the Spark engine (Catalyst and Tungstene). Recall that when possible, **Spark SQL is the recommended API to analyse data** that is built on top of RDD's except you have low-level code to perform or work with very unstructured data.
# See [RDD vs DataFrame vs DataSet](https://data-flair.training/blogs/apache-spark-rdd-vs-dataframe-vs-dataset/) for a comprehensive comparison (*Dataset* API is only available in Scala language).
#
#
# Finally we will see a basic application of a machine learning algorithm that will be trained at scale through **SparkML/MLlib pipelines**.
#
# *Nota*: Spark streaming (Dstreams and Structured streaming) and Graph API are not covered in this notebook.
#
# For an introduction to the main Spark concepts, pleaser refer to the [confluence page](https://confluence.airbus.corp/display/E2H89ATAR/Introduction+to+Spark).

# %% [markdown]
# ## 1. Spark Configuration
#
# Before doing any calculation, Spark needs to be configured. To do that, you have to create a **SparkSession** that set the entry point to the master node of the cluster. With this object, you can either connect to the master node and inherit from the basic configuration of the cluster, or you can set the ressources you need for your application.
#
# *Nota*: In previous version, you had to create a SparkContext before, this is now encapsulated in SparkSession.

# %%
# Some imports

# Spark
import pyspark
from pyspark.sql import SparkSession


# Pandas
import pandas as pd

# Plot
# %matplotlib inline
import matplotlib.pyplot as plt

# Foundry
import foundrywrapper
from foundrywrapper import FoundryWrapper

# %%
#Required for foundry, not useful for spark purposes
fw = FoundryWrapper()
fw
# Out:
# Foundry-Wrapper v0.3.3
# Welcome JEREMY PIRARD (PIRARD_J)

# %% [markdown]
# The SparkSession is set with the master node URL, and we overide it with a custom config.
# Here we have the driver node that holds the main application. It is dedicated at negociating ressources with the resources manager (e.g Kubernetes, YARN ...) and it is where the application is launched (typically the JAR of a spark application). We allocate 1 gigabyte of ram and 2 cpus.
#
# Then, for the workers, we use 2 executors (that are 2 JVM) with each 4 giga of RAM and 1 cores.
#
# This configuration should be enhanced with considering the computations that can be made, data size ...

# %%
spark = (SparkSession.builder 
        .master('spark://spark-master:7077') #master node URL
        .appName('~ Spark hands-on: RDD~') #my App name
        .config('spark.driver.memory', '1g') # memory allocated to the master
        .config('spark.driver.cores', '2') # CPU's allocated to the master
        .config('spark.executor.instances', '2') # how many executors
        .config('spark.executor.memory', '4g') # memory per executor (where the data is stored)
        .config('spark.executor.cores', '1') #CPU's per executor
        .config(conf=fw.spark.get_spark_app_config())
        .getOrCreate())
# Configuring spark to use Foundry
spark = fw.configure_spark(spark) # foundry specific

# %% [markdown]
# Printing the spark session, we see what version of Spark we are using (3.0) and we have access to the link to the *Spark UI*. This UI is really useful to manage the workload and to see the stages of the applications running. For instance, it can be useful to monitor the ressources used and adapt it consequently.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.196.77.12:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0-palantir.65</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>~ Spark hands-on: RDD~</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 2. Loading Datasets
#
# Spark has many connectors to interact with differents data format. The most common one are Parquet, JSON and csv ...

# %%
# Showing dataset stats
# Foundry wrapper
file_rid = fw.compass.get_rid('/datasources/flight_radar_24/data/cleaned/subsets/flight_radar_24_week')
fw.catalog.get_dataset_view_stats(file_rid)
# Out:
# ---------------------------------------------------------------------------
# ClientException                           Traceback (most recent call last)
# /opt/conda_share/envs/default/lib/python3.6/site-packages/foundrywrapper/CompassClient2.py in get_rid(self, path)
#      13         try:
# ---> 14             return self.resolve_path(path)[-1]['rid']
#      15         except ClientException as error:
#
# /opt/conda_share/envs/default/lib/python3.6/site-packages/pypalantir/v2/clients/CompassClient.py in resolve_path(self, path)
#      14     def resolve_path(self, path):
# ---> 15         return self.json(method='GET', url="/paths/{path}".format(path=path))
#      16
#
# /opt/conda_share/envs/default/lib/python3.6/site-packages/pypalantir/v2/clients/AbstractClient.py in json(self, method, **kwargs)
#      43     def json(self, method="GET", **kwargs):
# ---> 44         request = self.request(method, **kwargs)
#      45         try:
#
# /opt/conda_share/envs/default/lib/python3.6/site-packages/pypalantir/v2/clients/AbstractClient.py in request(self, method, **kwargs)
#      39         response = self.request_wrapper.request(method=method, **kwargs)
# ---> 40         self._check_status(method, kwargs['url'], response)
#      41         return response
#
# /opt/conda_share/envs/default/lib/python3.6/site-packages/pypalantir/v2/clients/AbstractClient.py in _check_status(self, method, path, response)
#      74                 ),
# ---> 75                 response,
#      76             )
#
# ClientException: Received 404 from server https://sectokenjhub on GET of https://sectokenjhub/compass/api/paths//datasources/flight_radar_24/data/cleaned/subsets/flight_radar_24_week
# -- BEGIN RECEIVED CONTENT --
# b'{"errorCode":"NOT_FOUND","errorName":"Compass:PathNotFound","errorInstanceId":"f7f2f90b-2df0-4546-8b9a-f61503004be8","parameters":{"path":"/datasources/flight_radar_24/data/cleaned/subsets/flight_radar_24_week"}}'
# -- END RECEIVED CONTENT --
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-9bc61a19734b> in <module>
#       1 # Showing dataset stats
#       2 # Foundry wrapper
# ----> 3 file_rid = fw.compass.get_rid('/datasources/flight_radar_24/data/cleaned/subsets/flight_radar_24_week')
#       4 fw.catalog.get_dataset_view_stats(file_rid)
#
# /opt/conda_share/envs/default/lib/python3.6/site-packages/foundrywrapper/CompassClient2.py in get_rid(self, path)
#      16             try:
#      17                 exception_class = loads(error.response.content)[
# ---> 18                     'exceptionClass']
#      19             except (TypeError, ValueError):
#      20                 raise error
#
# KeyError: 'exceptionClass'

# %% [markdown]
# Let's use the Fligth Radar 24 dataset. This is a parquet file and we can load it into a DataFrame object in a one line command.

# %%
# %%time
df = spark.read.parquet(fw.spark.foundryfs_uri(file_rid))

# %%
df.printSchema() #helps visualizing what's inside a dataframe

# %% [markdown]
# The Dataframe API is recommended to manipulate data, but let's first use RDDs to have an insight of the spark core components ...

# %%
# %%time
rdd = df.rdd
# Out:
# CPU times: user 773 µs, sys: 2.51 ms, total: 3.28 ms
# Wall time: 1.38 s

# %% [markdown]
# What does the data looks like in a RDD format ?

# %%
# %%time
rdd.take(5)
# Out:
# CPU times: user 10.2 ms, sys: 4.53 ms, total: 14.8 ms
# Wall time: 9.2 s
# [Row(flight_id=87404301, aircraft_id=11012303, aircraft_registration='N617AR', equipment='rv6', departure_airport_code=None, scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number=None, callsign=None, msn=None, elapsed_time_seconds=151, departure_date_time=datetime.datetime(2015, 1, 6, 15, 40, 27), arrival_date_time=datetime.datetime(2015, 1, 6, 15, 42, 58), airport_separation=None, track_distance=4.562991608717113, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 6, 15, 30, 6, 229200), off_time=datetime.datetime(2015, 1, 6, 15, 40, 27), on_time=datetime.datetime(2015, 1, 6, 15, 42, 58), in_time=datetime.datetime(2015, 1, 6, 15, 50, 3, 639400), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer=None, aircraft_family=None, aircraft_type=None, airline_iata=None, airline_icao=None, turnaround_time_minutes=None),
#  Row(flight_id=86757057, aircraft_id=5267244, aircraft_registration='OMBYL', equipment='YK40', departure_airport_code='BTS', scheduled_arrival_airport_code='PRG', arrival_airport_code='PRG', flight_number=None, callsign='SSG1', msn=None, elapsed_time_seconds=2152, departure_date_time=datetime.datetime(2015, 1, 1, 6, 29, 18), arrival_date_time=datetime.datetime(2015, 1, 1, 7, 5, 10), airport_separation=164.50778511055304, track_distance=115.37601847332859, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 1, 6, 17, 40, 576200), off_time=datetime.datetime(2015, 1, 1, 6, 29, 18), on_time=datetime.datetime(2015, 1, 1, 7, 15, 23, 508220), in_time=datetime.datetime(2015, 1, 1, 7, 30, 20, 328400), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Yakovlev', aircraft_family='Yak-40', aircraft_type='Yak-40', airline_iata=None, airline_icao='SSG', turnaround_time_minutes=None),
#  Row(flight_id=86761336, aircraft_id=5267244, aircraft_registration='OMBYL', equipment='YK40', departure_airport_code='TAT', scheduled_arrival_airport_code='BTS', arrival_airport_code='BTS', flight_number=None, callsign='SSG1', msn=None, elapsed_time_seconds=1775, departure_date_time=datetime.datetime(2015, 1, 1, 8, 11, 43), arrival_date_time=datetime.datetime(2015, 1, 1, 8, 41, 18), airport_separation=132.12782100251258, track_distance=115.24480734281174, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 1, 7, 35, 45, 803200), off_time=datetime.datetime(2015, 1, 1, 8, 7, 27, 918814), on_time=datetime.datetime(2015, 1, 1, 8, 41, 18), in_time=datetime.datetime(2015, 1, 1, 8, 47, 11, 326800), OOOI_quality_rating='WOOD', next_flight_id=86771171, next_arrival_airport_code='PRG', turnaround_time=9835, dist_between_in_and_next_out=0.2837841078157432, trt_quality_rating='WOOD', manufacturer='Yakovlev', aircraft_family='Yak-40', aircraft_type='Yak-40', airline_iata=None, airline_icao='SSG', turnaround_time_minutes=Decimal('163.916666666700000000')),
#  Row(flight_id=86771171, aircraft_id=5267244, aircraft_registration='OMBYL', equipment='YK40', departure_airport_code='BTS', scheduled_arrival_airport_code='PRG', arrival_airport_code='PRG', flight_number=None, callsign='SSG1', msn=None, elapsed_time_seconds=2066, departure_date_time=datetime.datetime(2015, 1, 1, 11, 41, 36), arrival_date_time=datetime.datetime(2015, 1, 1, 12, 16, 2), airport_separation=164.50778511055304, track_distance=114.6327337779092, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 1, 11, 31, 6, 508200), off_time=datetime.datetime(2015, 1, 1, 11, 41, 36), on_time=datetime.datetime(2015, 1, 1, 12, 25, 53, 836220), in_time=datetime.datetime(2015, 1, 1, 12, 40, 26, 488400), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Yakovlev', aircraft_family='Yak-40', aircraft_type='Yak-40', airline_iata=None, airline_icao='SSG', turnaround_time_minutes=None),
#  Row(flight_id=86775800, aircraft_id=5267244, aircraft_registration='OMBYL', equipment='YK40', departure_airport_code='TAT', scheduled_arrival_airport_code='BTS', arrival_airport_code='BTS', flight_number=None, callsign='SSG1', msn=None, elapsed_time_seconds=1827, departure_date_time=datetime.datetime(2015, 1, 1, 12, 58, 27), arrival_date_time=datetime.datetime(2015, 1, 1, 13, 28, 54), airport_separation=132.12782100251258, track_distance=116.56517518251339, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 1, 12, 23, 40, 948200), off_time=datetime.datetime(2015, 1, 1, 12, 54, 28, 650444), on_time=datetime.datetime(2015, 1, 1, 13, 28, 54), in_time=datetime.datetime(2015, 1, 1, 13, 34, 48, 931200), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Yakovlev', aircraft_family='Yak-40', aircraft_type='Yak-40', airline_iata=None, airline_icao='SSG', turnaround_time_minutes=None)]

# %% [markdown]
# Few comments here:
# - We first loaded a DataFrame object and then converted it to a RDD object. This is an anti-pattern and we will use later the DataFrame.
# - We see that the RDD contains some **Row** data type. This means we cannot manipulate it like we would do with a standard pandas DataFrame. This will also be handled using Spark SQL
# - Note that the two first instructions have been processed very rapidly. This is because they are **transformations**. Recall Spark is a lazy computing engine. That means, it has done nothing before we execute an **action** with the **take** function which is intended to print out some data.

# %% [markdown]
# ## 3. Transformations and actions

# %% [markdown]
# They are two types of operations you can apply on RDD Transformations and Actions. (This is the same for dataframe)
#
# - A Transformation allows to create a new RDD from an existing one.
# - An Action applies computation on the RDD and return a value (like the .count function)
#
# *Nota:* Recall that RDD is a resilient data format. Each RDD contains somehow a link to its "father" that allows the cluster to recreate it in case of failure.

# %% [markdown]
# ### Map
# **Map** is the most common **transformation**. It applies the same function to each entries of the RDD. Let's compute for each flight the flying duration.
#
# *Nota*: This is structured data.

# %%
time_duration = rdd.map(lambda x: x.arrival_date_time - x.departure_date_time)

# %% [markdown]
# ### take
#
# **Take** is a common **action** that will print out few result lines. Be careful, calling take will execute all the transformations that leads to the result !

# %%
time_duration.take(5)
# Out:
# [datetime.timedelta(0, 151),
#  datetime.timedelta(0, 2152),
#  datetime.timedelta(0, 1775),
#  datetime.timedelta(0, 2066),
#  datetime.timedelta(0, 1827)]

# %% [markdown]
# To bad, we lose the link between the obseration and the result. Concatenating the result with the initial RDD allows to keep this link. But take care, now our RDD is of type (Row, datetime.timedelta)

# %%
time_duration_concatenated = rdd.map(lambda x: (x,x.arrival_date_time - x.departure_date_time))
time_duration_concatenated.take(1)
# Out:
# [(Row(flight_id=87404301, aircraft_id=11012303, aircraft_registration='N617AR', equipment='rv6', departure_airport_code=None, scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number=None, callsign=None, msn=None, elapsed_time_seconds=151, departure_date_time=datetime.datetime(2015, 1, 6, 15, 40, 27), arrival_date_time=datetime.datetime(2015, 1, 6, 15, 42, 58), airport_separation=None, track_distance=4.562991608717113, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 6, 15, 30, 6, 229200), off_time=datetime.datetime(2015, 1, 6, 15, 40, 27), on_time=datetime.datetime(2015, 1, 6, 15, 42, 58), in_time=datetime.datetime(2015, 1, 6, 15, 50, 3, 639400), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer=None, aircraft_family=None, aircraft_type=None, airline_iata=None, airline_icao=None, turnaround_time_minutes=None),
#   datetime.timedelta(0, 151))]

# %% [markdown]
# Inside the map function, you can specify your own function as well. let's make a example that will concatenate departure airport code with arrival_airport_code.

# %%
def concatenate_airport_codes(x):
    if (x.departure_airport_code is None) | (x.arrival_airport_code is None):
        res = ""
    else:
        res = x.departure_airport_code + "_" + x.arrival_airport_code
    return res

# %%
rdd.map(concatenate_airport_codes).take(2) #One transformation followed by one action
# Out:
# ['', 'BTS_PRG']

# %% [markdown]
# ### Count

# %% [markdown]
# Let's count how many flight have flight from "TAT" airport and compute the percentage within the all database:

# %%
# %%time
tat_departure_count = rdd.filter(lambda x : x.departure_airport_code == "TAT") \
                .count()
percentage_tat_departure = tat_departure_count / rdd.count() * 100
print(percentage_tat_departure)
# Out:
# 0.0024280132023217875
# CPU times: user 22.9 ms, sys: 6.86 ms, total: 29.7 ms
# Wall time: 31.7 s

# %% [markdown]
# ### Collect
#
# This operation retrieves all the data into a python list. All the data are sent from the different workers to the master node. This is indeed an action that has to be used with care if you are working with a large dataset.

# %%
# We've seen that there is not a big percentage of flight coming from TAT airport, let's collect it safely !
rdd.filter(lambda x : x.departure_airport_code == "TAT").collect()
# Out:
# [Row(flight_id=86761336, aircraft_id=5267244, aircraft_registration='OMBYL', equipment='YK40', departure_airport_code='TAT', scheduled_arrival_airport_code='BTS', arrival_airport_code='BTS', flight_number=None, callsign='SSG1', msn=None, elapsed_time_seconds=1775, departure_date_time=datetime.datetime(2015, 1, 1, 8, 11, 43), arrival_date_time=datetime.datetime(2015, 1, 1, 8, 41, 18), airport_separation=132.12782100251258, track_distance=115.24480734281174, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 1, 7, 35, 45, 803200), off_time=datetime.datetime(2015, 1, 1, 8, 7, 27, 918814), on_time=datetime.datetime(2015, 1, 1, 8, 41, 18), in_time=datetime.datetime(2015, 1, 1, 8, 47, 11, 326800), OOOI_quality_rating='WOOD', next_flight_id=86771171, next_arrival_airport_code='PRG', turnaround_time=9835, dist_between_in_and_next_out=0.2837841078157432, trt_quality_rating='WOOD', manufacturer='Yakovlev', aircraft_family='Yak-40', aircraft_type='Yak-40', airline_iata=None, airline_icao='SSG', turnaround_time_minutes=Decimal('163.916666666700000000')),
#  Row(flight_id=86775800, aircraft_id=5267244, aircraft_registration='OMBYL', equipment='YK40', departure_airport_code='TAT', scheduled_arrival_airport_code='BTS', arrival_airport_code='BTS', flight_number=None, callsign='SSG1', msn=None, elapsed_time_seconds=1827, departure_date_time=datetime.datetime(2015, 1, 1, 12, 58, 27), arrival_date_time=datetime.datetime(2015, 1, 1, 13, 28, 54), airport_separation=132.12782100251258, track_distance=116.56517518251339, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 1, 12, 23, 40, 948200), off_time=datetime.datetime(2015, 1, 1, 12, 54, 28, 650444), on_time=datetime.datetime(2015, 1, 1, 13, 28, 54), in_time=datetime.datetime(2015, 1, 1, 13, 34, 48, 931200), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Yakovlev', aircraft_family='Yak-40', aircraft_type='Yak-40', airline_iata=None, airline_icao='SSG', turnaround_time_minutes=None),
#  Row(flight_id=87140258, aircraft_id=4837574, aircraft_registration='OKSLN', equipment='E135', departure_airport_code='TAT', scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number=None, callsign='ABP711', msn=None, elapsed_time_seconds=2223, departure_date_time=datetime.datetime(2015, 1, 4, 15, 30, 14), arrival_date_time=datetime.datetime(2015, 1, 4, 16, 7, 17), airport_separation=None, track_distance=190.0698726799681, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 4, 14, 51, 11, 979200), off_time=datetime.datetime(2015, 1, 4, 15, 25, 15, 452558), on_time=datetime.datetime(2015, 1, 4, 16, 18, 6, 429560), in_time=datetime.datetime(2015, 1, 4, 16, 33, 43, 308200), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Embraer', aircraft_family='ERJ145', aircraft_type='ERJ135', airline_iata=None, airline_icao='ABP', turnaround_time_minutes=None),
#  Row(flight_id=87023785, aircraft_id=4343210, aircraft_registration='VQBTL', equipment='A319', departure_airport_code='TAT', scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number='NN6292', callsign=None, msn=None, elapsed_time_seconds=8198, departure_date_time=datetime.datetime(2015, 1, 3, 16, 3, 41), arrival_date_time=datetime.datetime(2015, 1, 3, 18, 20, 19), airport_separation=None, track_distance=832.4715250676986, adsb_start_flight_phase='stationary', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 3, 16, 3, 41), off_time=datetime.datetime(2015, 1, 3, 16, 17, 13), on_time=datetime.datetime(2015, 1, 3, 18, 20, 19), in_time=datetime.datetime(2015, 1, 3, 18, 26, 37, 768000), OOOI_quality_rating='BRONZE', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Airbus', aircraft_family='A320', aircraft_type='A319', airline_iata='NN', airline_icao=None, turnaround_time_minutes=None),
#  Row(flight_id=87521747, aircraft_id=3981324, aircraft_registration='DCAAM', equipment='D228', departure_airport_code='TAT', scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number=None, callsign='AZE32B', msn=None, elapsed_time_seconds=8651, departure_date_time=datetime.datetime(2015, 1, 7, 13, 41, 52), arrival_date_time=datetime.datetime(2015, 1, 7, 16, 6, 3), airport_separation=None, track_distance=520.0060880833555, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 7, 13, 3, 47, 201200), off_time=datetime.datetime(2015, 1, 7, 13, 37, 6, 909826), on_time=datetime.datetime(2015, 1, 7, 16, 12, 56, 746560), in_time=datetime.datetime(2015, 1, 7, 16, 24, 10, 798200), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Fairchild-Dornier', aircraft_family='Do 228', aircraft_type='Do 228', airline_iata=None, airline_icao='AZE', turnaround_time_minutes=None),
#  Row(flight_id=86795638, aircraft_id=4666383, aircraft_registration='HALPO', equipment='A320', departure_airport_code='TAT', scheduled_arrival_airport_code='LTN', arrival_airport_code='LTN', flight_number='W67691', callsign='WZZ8TV', msn=3384, elapsed_time_seconds=8472, departure_date_time=datetime.datetime(2015, 1, 1, 17, 22, 24), arrival_date_time=datetime.datetime(2015, 1, 1, 19, 43, 36), airport_separation=802.5215819096114, track_distance=826.2448612383223, adsb_start_flight_phase='ground_fast', adsb_end_flight_phase='stationary', out_time=datetime.datetime(2015, 1, 1, 17, 18, 23, 107200), off_time=datetime.datetime(2015, 1, 1, 17, 26, 33), on_time=datetime.datetime(2015, 1, 1, 19, 38, 55), in_time=datetime.datetime(2015, 1, 1, 19, 43, 36), OOOI_quality_rating='SILVER', next_flight_id=86813785, next_arrival_airport_code='GDN', turnaround_time=3124, dist_between_in_and_next_out=1.010681780675617, trt_quality_rating='WOOD', manufacturer='Airbus', aircraft_family='A320', aircraft_type='A320', airline_iata='W6', airline_icao='WZZ', turnaround_time_minutes=Decimal('52.066666666700000000')),
#  Row(flight_id=87031962, aircraft_id=4666383, aircraft_registration='HALPO', equipment='A320', departure_airport_code='TAT', scheduled_arrival_airport_code='LTN', arrival_airport_code='LTN', flight_number='W67691', callsign='WZZ8TV', msn=3384, elapsed_time_seconds=9522, departure_date_time=datetime.datetime(2015, 1, 3, 17, 18, 53), arrival_date_time=datetime.datetime(2015, 1, 3, 19, 57, 35), airport_separation=802.5215819096114, track_distance=821.6329418252701, adsb_start_flight_phase='ground_slow', adsb_end_flight_phase='ground_slow', out_time=datetime.datetime(2015, 1, 3, 17, 18, 53), off_time=datetime.datetime(2015, 1, 3, 17, 22, 17), on_time=datetime.datetime(2015, 1, 3, 19, 51, 54), in_time=datetime.datetime(2015, 1, 3, 19, 57, 35), OOOI_quality_rating='GOLD', next_flight_id=87054390, next_arrival_airport_code='GDN', turnaround_time=3077, dist_between_in_and_next_out=0.03154095798806871, trt_quality_rating='SILVER', manufacturer='Airbus', aircraft_family='A320', aircraft_type='A320', airline_iata='W6', airline_icao='WZZ', turnaround_time_minutes=Decimal('51.283333333300000000')),
#  Row(flight_id=87415463, aircraft_id=4660901, aircraft_registration='HALPT', equipment='A320', departure_airport_code='TAT', scheduled_arrival_airport_code='LTN', arrival_airport_code='LTN', flight_number='W67691', callsign='WZZ8TV', msn=3807, elapsed_time_seconds=8559, departure_date_time=datetime.datetime(2015, 1, 6, 17, 22, 36), arrival_date_time=datetime.datetime(2015, 1, 6, 19, 45, 15), airport_separation=802.5215819096114, track_distance=815.3228223379098, adsb_start_flight_phase='ground_fast', adsb_end_flight_phase='stationary', out_time=datetime.datetime(2015, 1, 6, 17, 17, 46, 411200), off_time=datetime.datetime(2015, 1, 6, 17, 25, 41), on_time=datetime.datetime(2015, 1, 6, 19, 40, 56), in_time=datetime.datetime(2015, 1, 6, 19, 43, 35), OOOI_quality_rating='SILVER', next_flight_id=87435687, next_arrival_airport_code='GDN', turnaround_time=2389, dist_between_in_and_next_out=0.07227987302153281, trt_quality_rating='GOLD', manufacturer='Airbus', aircraft_family='A320', aircraft_type='A320', airline_iata='W6', airline_icao='WZZ', turnaround_time_minutes=Decimal('39.816666666700000000')),
#  Row(flight_id=87373159, aircraft_id=4837600, aircraft_registration='OKJNT', equipment='E35L', departure_airport_code='TAT', scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number=None, callsign='ABP751', msn=None, elapsed_time_seconds=1247, departure_date_time=datetime.datetime(2015, 1, 6, 9, 56, 42), arrival_date_time=datetime.datetime(2015, 1, 6, 10, 17, 29), airport_separation=None, track_distance=121.02913301919016, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 6, 9, 21, 25, 348200), off_time=datetime.datetime(2015, 1, 6, 9, 52, 36, 454044), on_time=datetime.datetime(2015, 1, 6, 10, 19, 57, 150500), in_time=datetime.datetime(2015, 1, 6, 10, 23, 59, 571800), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Embraer', aircraft_family='ERJ145', aircraft_type='Legacy 600', airline_iata=None, airline_icao='ABP', turnaround_time_minutes=None),
#  Row(flight_id=87404354, aircraft_id=4837527, aircraft_registration='OKROM', equipment='E35L', departure_airport_code='TAT', scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number=None, callsign='ABP745', msn=None, elapsed_time_seconds=1336, departure_date_time=datetime.datetime(2015, 1, 6, 15, 40, 54), arrival_date_time=datetime.datetime(2015, 1, 6, 16, 3, 10), airport_separation=None, track_distance=120.96310732491736, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 6, 15, 3, 56, 62200), off_time=datetime.datetime(2015, 1, 6, 15, 36, 24, 633960), on_time=datetime.datetime(2015, 1, 6, 16, 4, 43, 558000), in_time=datetime.datetime(2015, 1, 6, 16, 9, 20, 58400), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Embraer', aircraft_family='ERJ145', aircraft_type='Legacy 600', airline_iata=None, airline_icao='ABP', turnaround_time_minutes=None),
#  Row(flight_id=87550001, aircraft_id=4837600, aircraft_registration='OKJNT', equipment='E35L', departure_airport_code='TAT', scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number=None, callsign='ABP751', msn=None, elapsed_time_seconds=1436, departure_date_time=datetime.datetime(2015, 1, 7, 17, 49, 30), arrival_date_time=datetime.datetime(2015, 1, 7, 18, 13, 26), airport_separation=None, track_distance=115.95963820764975, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 7, 17, 14, 19, 774200), off_time=datetime.datetime(2015, 1, 7, 17, 45, 25, 965288), on_time=datetime.datetime(2015, 1, 7, 18, 15, 17, 27600), in_time=datetime.datetime(2015, 1, 7, 18, 19, 27, 578000), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Embraer', aircraft_family='ERJ145', aircraft_type='Legacy 600', airline_iata=None, airline_icao='ABP', turnaround_time_minutes=None),
#  Row(flight_id=86985947, aircraft_id=5276113, aircraft_registration='URDNP', equipment='E145', departure_airport_code='TAT', scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number='7W5556', callsign='WRC5556', msn=None, elapsed_time_seconds=4771, departure_date_time=datetime.datetime(2015, 1, 3, 7, 54, 47), arrival_date_time=datetime.datetime(2015, 1, 3, 9, 14, 18), airport_separation=None, track_distance=536.5051252137187, adsb_start_flight_phase='ascent', adsb_end_flight_phase='cruise', out_time=datetime.datetime(2015, 1, 3, 7, 18, 25, 476200), off_time=datetime.datetime(2015, 1, 3, 7, 50, 26, 197676), on_time=datetime.datetime(2015, 1, 3, 9, 38, 54, 920700), in_time=datetime.datetime(2015, 1, 3, 10, 9, 54, 594000), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Embraer', aircraft_family='ERJ145', aircraft_type='ERJ145', airline_iata='7W', airline_icao='WRC', turnaround_time_minutes=None),
#  Row(flight_id=87010004, aircraft_id=5276113, aircraft_registration='URDNP', equipment='E145', departure_airport_code='TAT', scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number='7W5558', callsign='WRC5558', msn=None, elapsed_time_seconds=4950, departure_date_time=datetime.datetime(2015, 1, 3, 13, 45, 49), arrival_date_time=datetime.datetime(2015, 1, 3, 15, 8, 19), airport_separation=None, track_distance=536.0601698207781, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 3, 13, 11, 8, 762200), off_time=datetime.datetime(2015, 1, 3, 13, 41, 52, 17760), on_time=datetime.datetime(2015, 1, 3, 15, 30, 39, 441280), in_time=datetime.datetime(2015, 1, 3, 15, 59, 6, 916600), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Embraer', aircraft_family='ERJ145', aircraft_type='ERJ145', airline_iata='7W', airline_icao='WRC', turnaround_time_minutes=None),
#  Row(flight_id=87012403, aircraft_id=5254229, aircraft_registration='YLBBX', equipment='B733', departure_airport_code='TAT', scheduled_arrival_airport_code='RIX', arrival_airport_code='RIX', flight_number='BT486', callsign='BTI486', msn=None, elapsed_time_seconds=5520, departure_date_time=datetime.datetime(2015, 1, 3, 14, 12, 7), arrival_date_time=datetime.datetime(2015, 1, 3, 15, 44, 7), airport_separation=489.5728529739873, track_distance=534.9746857319891, adsb_start_flight_phase='ground_fast', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 3, 14, 6, 53, 63200), off_time=datetime.datetime(2015, 1, 3, 14, 15, 37), on_time=datetime.datetime(2015, 1, 3, 15, 44, 7), in_time=datetime.datetime(2015, 1, 3, 15, 49, 14, 143000), OOOI_quality_rating='BRONZE', next_flight_id=87138328, next_arrival_airport_code='SVO', turnaround_time=83666, dist_between_in_and_next_out=1.0985517096024737, trt_quality_rating='WOOD', manufacturer='Boeing', aircraft_family='B737', aircraft_type='B737-00', airline_iata='BT', airline_icao='BTI', turnaround_time_minutes=Decimal('1394.433333333300000000')),
#  Row(flight_id=87001920, aircraft_id=5276204, aircraft_registration='URWRJ', equipment='A321', departure_airport_code='TAT', scheduled_arrival_airport_code='KBP', arrival_airport_code='KBP', flight_number='7W7472', callsign='WRC7472', msn=1869, elapsed_time_seconds=4901, departure_date_time=datetime.datetime(2015, 1, 3, 12, 11, 7), arrival_date_time=datetime.datetime(2015, 1, 3, 13, 32, 48), airport_separation=419.93639772505986, track_distance=467.79262711640075, adsb_start_flight_phase='ground_slow', adsb_end_flight_phase='ground_slow', out_time=datetime.datetime(2015, 1, 3, 12, 11, 7), off_time=datetime.datetime(2015, 1, 3, 12, 18, 16), on_time=datetime.datetime(2015, 1, 3, 13, 26, 30), in_time=datetime.datetime(2015, 1, 3, 13, 31, 5), OOOI_quality_rating='GOLD', next_flight_id=87921123, next_arrival_airport_code='TAT', turnaround_time=588960, dist_between_in_and_next_out=1.043292161139336, trt_quality_rating='WOOD', manufacturer='Airbus', aircraft_family='A320', aircraft_type='A321', airline_iata='7W', airline_icao='WRC', turnaround_time_minutes=Decimal('9816.000000000000000000')),
#  Row(flight_id=87373897, aircraft_id=4456488, aircraft_registration='OEGPS', equipment='C55B', departure_airport_code='TAT', scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number=None, callsign='TYW822S', msn=None, elapsed_time_seconds=2446, departure_date_time=datetime.datetime(2015, 1, 6, 10, 8, 44), arrival_date_time=datetime.datetime(2015, 1, 6, 10, 49, 30), airport_separation=None, track_distance=218.28189399701125, adsb_start_flight_phase='ascent', adsb_end_flight_phase='descent', out_time=datetime.datetime(2015, 1, 6, 9, 28, 53, 19200), off_time=datetime.datetime(2015, 1, 6, 10, 3, 33, 938318), on_time=datetime.datetime(2015, 1, 6, 10, 54, 26, 880300), in_time=datetime.datetime(2015, 1, 6, 11, 3, 30, 606000), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer='Beechcraft', aircraft_family='Baron', aircraft_type='B55', airline_iata=None, airline_icao='TYW', turnaround_time_minutes=None)]

# %% [markdown]
# *Nota*: Every transformation creates a new RDD. It is good practice to create a pipeline of transformations to have a concise coding with a clear view on the transformations.

# %% [markdown]
# ### Operations betweens two RDD's
#
# Apply a function on RDD A et B than will produce a third RDD
#
# For instance: **subtract**. Let's create a new RDD that does not contains departure_airport_code == "TAT" using preceding RDD's. This toy example would be equivalent to a filter transformation.

# %%
# We have our initial RDD called rdd
# First, let's compute a RDD containing the TAT code

tat_rdd = rdd.filter(lambda x : x.departure_airport_code == "TAT")

not_tat_rdd = rdd.subtract(tat_rdd) #would be the same as doing rdd.filter(lambda x : x.departure_airport_code != "TAT")

not_tat_rdd.take(1)
# Out:
# [Row(flight_id=86826850, aircraft_id=11092606, aircraft_registration='N696RG', equipment='WW24', departure_airport_code=None, scheduled_arrival_airport_code=None, arrival_airport_code=None, flight_number=None, callsign='4', msn=None, elapsed_time_seconds=1010, departure_date_time=datetime.datetime(2015, 1, 1, 23, 7, 20), arrival_date_time=datetime.datetime(2015, 1, 1, 23, 24, 10), airport_separation=None, track_distance=133.73038445955518, adsb_start_flight_phase='ascent', adsb_end_flight_phase='cruise', out_time=datetime.datetime(2015, 1, 1, 22, 7, 32, 100200), off_time=datetime.datetime(2015, 1, 1, 22, 57, 28, 451132), on_time=datetime.datetime(2015, 1, 1, 23, 48, 29, 203840), in_time=datetime.datetime(2015, 1, 2, 0, 19, 9, 119800), OOOI_quality_rating='WOOD', next_flight_id=None, next_arrival_airport_code=None, turnaround_time=None, dist_between_in_and_next_out=None, trt_quality_rating=None, manufacturer=None, aircraft_family=None, aircraft_type=None, airline_iata=None, airline_icao=None, turnaround_time_minutes=None)]

# %% [markdown]
# ### Reduce
#
# This is an aggregation function that leads to a single element.
# For instance let's implement another way to count the number of departure_airport_code==TAT using a map/reduce style.

# %%
tat_rdd_keyed = tat_rdd.map(lambda x : 1) # transformation: we map a 1 to every observation
tat_count = tat_rdd_keyed.reduce(lambda x,y :  x+y)
print(tat_count) #not a rdd !
# Out:
# 16

# %% [markdown]
# ### countByKey, reduceByKey ...
# What if we want to compute this to all the different departure airports ?
# The countByKey function allows to do this for key/value RDD. There are many other actions function on these type of RDD (see the docs :) )

# %%
keyed_rdd = rdd.map(lambda x : (x.departure_airport_code, 1)) # create a key value (departure_airport, 1)

# %% [markdown]
# We could have passed in the value field whatever we wanted. For instance, we could have written (x.key, x), so now the values would be accessed by a particular key.
# The interest of doing that is to get grouped result (can be equivalent to some GroupBy in Spark SQL or pandas)

# %%
counted_departure = keyed_rdd.reduceByKey(lambda x,y : x+y)
# Here it takes a (String, Int) type and it will just groupby the keys and count them efficiently
# If it was not grouped by key you would get an error since you can't sum such a tuple!

# %%
counted_departure.collect()
# Out:
# [(None, 154461),
#  ('FLL', 2167),
#  ('SHV', 141),
#  ('SIN', 3260),
#  ('MCO', 2772),
#  ('TMB', 6),
#  ('MSY', 807),
#  ('MAN', 1307),
#  ('TLV', 1480),
#  ('EYW', 134),
#  ('PHF', 75),
#  ('CRQ', 4),
#  ('SFB', 214),
#  ('MNZ', 11),
#  ('DME', 2230),
#  ('GRU', 2093),
#  ('UFA', 150),
#  ('SIP', 156),
#  ('TFS', 654),
#  ('CUN', 1323),
#  ('CEK', 84),
#  ('UIO', 258),
#  ('SSH', 139),
#  ('FNJ', 2),
#  ('VVO', 102),
#  ('HTA', 20),
#  ('VKO', 1048),
#  ('ONT', 624),
#  ('EDC', 9),
#  ('AUS', 1005),
#  ('MFE', 110),
#  ('AGU', 49),
#  ('BJX', 109),
#  ('TJM', 68),
#  ('VSA', 70),
#  ('SJD', 288),
#  ('CJS', 47),
#  ('CME', 26),
#  ('ZIH', 49),
#  ('REX', 20),
#  ('IAH', 5140),
#  ('OTP', 759),
#  ('VER', 82),
#  ('OVS', 1),
#  ('RYG', 104),
#  ('MST', 77),
#  ('GRI', 18),
#  ('MTH', 7),
#  ('LGB', 445),
#  ('GYN', 138),
#  ('SAN', 1683),
#  ('CBG', 46),
#  ('BZZ', 25),
#  ('ACT', 80),
#  ('DWH', 16),
#  ('LCH', 38),
#  ('DBQ', 20),
#  ('ACH', 18),
#  ('AOH', 1),
#  ('LPL', 307),
#  ('MRY', 180),
#  ('MVY', 15),
#  ('GSE', 20),
#  ('OXF', 125),
#  ('DUS', 1544),
#  ('BRQ', 36),
#  ('SYD', 2630),
#  ('TXL', 1383),
#  ('KUN', 42),
#  ('CUF', 22),
#  ('KID', 4),
#  ('TRS', 78),
#  ('TRN', 318),
#  ('ILM', 138),
#  ('RZE', 60),
#  ('CGN', 787),
#  ('ACY', 91),
#  ('MEM', 1802),
#  ('HVB', 28),
#  ('ADL', 753),
#  ('PRB', 3),
#  ('ALB', 257),
#  ('ABE', 112),
#  ('LFT', 105),
#  ('FMY', 28),
#  ('TEB', 189),
#  ('OOL', 474),
#  ('GLA', 589),
#  ('MOB', 119),
#  ('IDA', 35),
#  ('CRE', 5),
#  ('EAR', 3),
#  ('EUG', 137),
#  ('CLD', 60),
#  ('MYF', 15),
#  ('LUX', 393),
#  ('AMA', 102),
#  ('ECG', 1),
#  ('ABQ', 423),
#  ('FAT', 256),
#  ('YYR', 2),
#  ('TLL', 254),
#  ('SEN', 124),
#  ('HUT', 2),
#  ('ORL', 19),
#  ('TIJ', 425),
#  ('SGF', 150),
#  ('MCI', 894),
#  ('GAI', 3),
#  ('LCJ', 24),
#  ('MSO', 68),
#  ('MHT', 250),
#  ('AIK', 3),
#  ('DTW', 2934),
#  ('DCA', 2392),
#  ('IND', 1071),
#  ('BOI', 294),
#  ('PDX', 1268),
#  ('CVG', 1001),
#  ('SCK', 8),
#  ('RAP', 99),
#  ('KIH', 112),
#  ('DXB', 3730),
#  ('CLE', 777),
#  ('HOG', 42),
#  ('MLI', 116),
#  ('SCU', 10),
#  ('BHM', 313),
#  ('BMI', 60),
#  ('TOL', 40),
#  ('ELM', 61),
#  ('SYZ', 37),
#  ('DJJ', 151),
#  ('LRD', 74),
#  ('USA', 8),
#  ('GTF', 46),
#  ('TRI', 57),
#  ('LCK', 31),
#  ('FWA', 139),
#  ('CNS', 408),
#  ('IKA', 292),
#  ('AWZ', 49),
#  ('SOC', 80),
#  ('EAU', 21),
#  ('NCL', 302),
#  ('ABZ', 422),
#  ('LRT', 23),
#  ('SNR', 12),
#  ('KJA', 92),
#  ('XCR', 6),
#  ('YQX', 20),
#  ('JAC', 74),
#  ('SBA', 170),
#  ('CRL', 403),
#  ('MUC', 2710),
#  ('VPS', 128),
#  ('ISN', 58),
#  ('QRO', 48),
#  ('ERI', 41),
#  ('YYT', 89),
#  ('YXU', 108),
#  ('AEX', 63),
#  ('HOB', 9),
#  ('YQB', 186),
#  ('LAW', 25),
#  ('SWO', 5),
#  ('FLG', 29),
#  ('COU', 34),
#  ('CHO', 60),
#  ('MLU', 48),
#  ('BRU', 1684),
#  ('OSL', 1753),
#  ('FTW', 25),
#  ('CEC', 14),
#  ('GET', 50),
#  ('OSI', 3),
#  ('BFL', 100),
#  ('ZAG', 299),
#  ('UST', 17),
#  ('LNO', 8),
#  ('HAJ', 395),
#  ('AMS', 3930),
#  ('ALG', 453),
#  ('BFS', 304),
#  ('TOS', 195),
#  ('TRD', 341),
#  ('FAY', 43),
#  ('MLE', 290),
#  ('KDM', 9),
#  ('ITH', 43),
#  ('MQN', 7),
#  ('DRV', 13),
#  ('GAN', 11),
#  ('BNN', 20),
#  ('BOO', 103),
#  ('BQN', 52),
#  ('YHM', 91),
#  ('AFW', 27),
#  ('VLC', 349),
#  ('HAM', 1014),
#  ('OVD', 83),
#  ('LJU', 180),
#  ('RHI', 8),
#  ('HLN', 15),
#  ('STR', 723),
#  ('SBZ', 31),
#  ('IST', 4938),
#  ('CLJ', 104),
#  ('POZ', 101),
#  ('LWO', 40),
#  ('FCA', 41),
#  ('SKP', 108),
#  ('ILD', 2),
#  ('SID', 65),
#  ('SOF', 350),
#  ('TUN', 397),
#  ('BGO', 446),
#  ('PMO', 319),
#  ('DBV', 31),
#  ('NEW', 9),
#  ('RLG', 12),
#  ('GRX', 63),
#  ('VGO', 56),
#  ('OPO', 614),
#  ('TVC', 66),
#  ('MAH', 48),
#  ('RBD', 6),
#  ('YYG', 22),
#  ('CFR', 13),
#  ('YYJ', 116),
#  ('CSY', 3),
#  ('IMT', 6),
#  ('YQM', 102),
#  ('EGO', 11),
#  ('NEV', 1),
#  ('ELH', 4),
#  ('AGC', 9),
#  ('GKY', 3),
#  ('VCV', 13),
#  ('OSU', 4),
#  ('HLA', 96),
#  ('PLO', 21),
#  ('UGN', 3),
#  ('WYA', 14),
#  ('EKI', 1),
#  ('FYV', 3),
#  ('VGT', 9),
#  ('BOJ', 24),
#  ('CNO', 7),
#  ('HBA', 208),
#  ('TEX', 2),
#  ('BJC', 4),
#  ('SCF', 16),
#  ('SUN', 31),
#  ('LSE', 22),
#  ('GUF', 2),
#  ('GLD', 2),
#  ('PDK', 34),
#  ('LTO', 6),
#  ('EOH', 3),
#  ('ERV', 2),
#  ('NQY', 48),
#  ('CSO', 7),
#  ('BWE', 21),
#  ('SWF', 65),
#  ('LPI', 40),
#  ('UIN', 1),
#  ('AEP', 323),
#  ('EXT', 118),
#  ('ARU', 14),
#  ('HHH', 19),
#  ('DOU', 13),
#  ('TBI', 1),
#  ('MIM', 20),
#  ('OIT', 98),
#  ('REC', 506),
#  ('NVT', 44),
#  ('MCZ', 148),
#  ('LDB', 70),
#  ('ASU', 44),
#  ('DHT', 2),
#  ('LCY', 583),
#  ('BIE', 1),
#  ('HYA', 3),
#  ('CCB', 2),
#  ('BDR', 1),
#  ('SMO', 10),
#  ('CGI', 1),
#  ('MQY', 4),
#  ('AKL', 1142),
#  ('CTS', 670),
#  ('PVG', 3376),
#  ('HKG', 4374),
#  ('ADD', 302),
#  ('ICN', 2714),
#  ('AUH', 1471),
#  ('GIG', 1067),
#  ('CAI', 822),
#  ('DZA', 12),
#  ('TPE', 2069),
#  ('BGI', 213),
#  ('MBJ', 265),
#  ('SCL', 1141),
#  ('HYD', 718),
#  ('RUH', 1424),
#  ('DAC', 319),
#  ('HAN', 894),
#  ('KUL', 3490),
#  ('ABV', 87),
#  ('CGP', 92),
#  ('CCU', 771),
#  ('AMM', 498),
#  ('SGN', 1768),
#  ('TSA', 412),
#  ('ALA', 351),
#  ('GEO', 36),
#  ('KMQ', 57),
#  ('POA', 425),
#  ('DLC', 632),
#  ('OBO', 45),
#  ('BSB', 1075),
#  ('OKJ', 94),
#  ('VDA', 5),
#  ('CEB', 504),
#  ('IKT', 93),
#  ('MAO', 193),
#  ('DPS', 1243),
#  ('SNU', 60),
#  ('POP', 59),
#  ('SKD', 12),
#  ('CZL', 50),
#  ('TAK', 107),
#  ('LRM', 32),
#  ('EVN', 145),
#  ('GDX', 10),
#  ('PPG', 2),
#  ('NBE', 54),
#  ('SEZ', 52),
#  ('SAP', 68),
#  ('IWK', 25),
#  ('BEL', 242),
#  ('STI', 109),
#  ('TOY', 22),
#  ('KTM', 250),
#  ('MDE', 440),
#  ('CGQ', 395),
#  ('ROV', 177),
#  ('CSX', 797),
#  ('ZQW', 22),
#  ('CMB', 525),
#  ('KMG', 1998),
#  ('HRB', 699),
#  ('YCD', 13),
#  ('HER', 69),
#  ('COF', 3),
#  ('MCX', 17),
#  ('LFW', 34),
#  ('AUA', 171),
#  ('AMD', 307),
#  ('LIR', 87),
#  ('MCN', 2),
#  ('KVD', 18),
#  ('LPB', 95),
#  ('SKB', 45),
#  ('FEG', 11),
#  ('PLS', 86),
#  ('KXK', 1),
#  ('GUW', 43),
#  ('FNC', 209),
#  ('BOD', 395),
#  ('MGA', 81),
#  ('CJU', 975),
#  ('BDJ', 207),
#  ('PUS', 594),
#  ('HIN', 10),
#  ('FOC', 599),
#  ('BTJ', 53),
#  ('WUH', 1198),
#  ('WNZ', 381),
#  ('BPN', 474),
#  ('JJN', 197),
#  ('SWA', 157),
#  ('UTH', 160),
#  ('NST', 66),
#  ('CNX', 561),
#  ('TPS', 64),
#  ('IBR', 50),
#  ('KKJ', 128),
#  ('TWU', 82),
#  ('UBP', 73),
#  ('KCH', 350),
#  ('WEH', 64),
#  ('KBR', 193),
#  ('YGJ', 46),
#  ('LOP', 185),
#  ('PNQ', 277),
#  ('MZO', 2),
#  ('ESB', 644),
#  ('WUS', 42),
#  ('AOR', 67),
#  ('USN', 32),
#  ('PNH', 203),
#  ('MCP', 35),
#  ('YNJ', 86),
#  ('TRK', 47),
#  ('NAT', 215),
#  ('ISA', 55),
#  ('BDO', 235),
#  ('JNZ', 10),
#  ('WEF', 37),
#  ('RMQ', 162),
#  ('XNN', 75),
#  ('NTL', 100),
#  ('MMY', 26),
#  ('NDG', 27),
#  ('LYG', 48),
#  ('SBW', 89),
#  ('OSS', 38),
#  ('WKJ', 6),
#  ('LBU', 49),
#  ('URT', 108),
#  ('NTG', 87),
#  ('HET', 154),
#  ('MFM', 478),
#  ('JGS', 23),
#  ('ADA', 307),
#  ('TZX', 155),
#  ('SAH', 44),
#  ('SHB', 3),
#  ('CJB', 87),
#  ('PVH', 36),
#  ('GZT', 100),
#  ('HIR', 6),
#  ('SZF', 99),
#  ('LIN', 829),
#  ('KOE', 98),
#  ('THE', 69),
#  ('LLW', 13),
#  ('IXB', 76),
#  ('BPS', 74),
#  ('BFJ', 11),
#  ('ELS', 31),
#  ('ROB', 5),
#  ('RBA', 45),
#  ('MSR', 19),
#  ('ERC', 13),
#  ('BSR', 49),
#  ('TRZ', 76),
#  ('NTQ', 7),
#  ('NAG', 115),
#  ('IXZ', 56),
#  ('TKK', 4),
#  ('SUF', 141),
#  ('HHN', 140),
#  ('FEZ', 58),
#  ('AHO', 80),
#  ('DIY', 85),
#  ('CHQ', 56),
#  ('VAS', 16),
#  ('BDS', 136),
#  ('CIH', 46),
#  ('HTY', 70),
#  ('BEM', 4),
#  ('BJA', 17),
#  ('ALF', 25),
#  ('BAL', 22),
#  ('BGG', 9),
#  ('TSF', 139),
#  ('IGR', 30),
#  ('TRF', 115),
#  ('BVA', 245),
#  ('APW', 27),
#  ('OSD', 37),
#  ('EZS', 61),
#  ('HBE', 154),
#  ('NDR', 52),
#  ('MWX', 29),
#  ('AJU', 82),
#  ('OUD', 34),
#  ('TXN', 25),
#  ('LZH', 54),
#  ('KYA', 29),
#  ('YSB', 65),
#  ('MDZ', 35),
#  ('UYN', 15),
#  ('VST', 23),
#  ('HMO', 69),
#  ('BRC', 43),
#  ('MOL', 32),
#  ('HAU', 53),
#  ('TTU', 2),
#  ('CAP', 4),
#  ('SLA', 18),
#  ('CZM', 49),
#  ('CRD', 14),
#  ('AHU', 2),
#  ('CBH', 4),
#  ('ABA', 13),
#  ('NQN', 20),
#  ('YBP', 46),
#  ('NJC', 27),
#  ('AYQ', 36),
#  ('LJG', 216),
#  ('LBD', 32),
#  ('ADE', 18),
#  ('MZH', 7),
#  ('KDH', 12),
#  ('NKT', 16),
#  ('DDG', 6),
#  ('TLK', 6),
#  ('TNR', 20),
#  ('BHY', 85),
#  ('SKT', 26),
#  ('NOJ', 11),
#  ('OSW', 6),
#  ('IGT', 6),
#  ('HIB', 2),
#  ('BHV', 1),
#  ('ELU', 1),
#  ('NLA', 9),
#  ('TEQ', 9),
#  ('BIQ', 74),
#  ('AZS', 12),
#  ('MJV', 19),
#  ('EDO', 4),
#  ('ASF', 31),
#  ('TBZ', 10),
#  ('CKY', 21),
#  ('DJG', 1),
#  ('HME', 3),
#  ('JNU', 18),
#  ('HLH', 4),
#  ('PBM', 18),
#  ('LUN', 33),
#  ('OGZ', 16),
#  ('CTG', 242),
#  ('MDQ', 7),
#  ('SIT', 2),
#  ('KTN', 21),
#  ('DNR', 9),
#  ('RES', 2),
#  ('CSG', 12),
#  ('HLP', 146),
#  ('KNH', 199),
#  ('NSI', 7),
#  ('KRW', 1),
#  ('RYK', 1),
#  ('EIL', 6),
#  ('LAF', 3),
#  ('MMK', 57),
#  ('OCF', 5),
#  ('VBS', 17),
#  ('PCL', 27),
#  ('SLY', 8),
#  ('HEA', 18),
#  ('YXS', 13),
#  ('JHL', 6),
#  ('QUO', 3),
#  ('YZR', 20),
#  ('MCE', 11),
#  ('ALS', 5),
#  ('YXC', 23),
#  ('LWS', 16),
#  ('RIW', 2),
#  ('PGA', 2),
#  ('PUF', 92),
#  ('LBL', 3),
#  ('KSM', 1),
#  ('SHR', 2),
#  ('CEZ', 2),
#  ('BMU', 22),
#  ('PKZ', 9),
#  ('WGP', 11),
#  ('MOC', 18),
#  ('SNW', 1),
#  ('SLU', 30),
#  ('THS', 7),
#  ('JTC', 17),
#  ('MII', 16),
#  ('CAC', 31),
#  ('TJL', 13),
#  ('IZA', 11),
#  ('PFB', 17),
#  ('GVR', 12),
#  ('MOF', 12),
#  ('THL', 3),
#  ('TTA', 8),
#  ('PAV', 5),
#  ('CMG', 5),
#  ('NVA', 10),
#  ('ERH', 3),
#  ('JOI', 19),
#  ('TCO', 4),
#  ('USM', 161),
#  ('MZL', 2),
#  ('AGH', 31),
#  ('LKA', 3),
#  ('EYP', 11),
#  ('TTE', 2),
#  ('OZG', 1),
#  ('EJA', 4),
#  ('IBE', 1),
#  ('RNB', 16),
#  ('KAW', 1),
#  ('MGZ', 1),
#  ('TVY', 1),
#  ('PSO', 9),
#  ('FLR', 209),
#  ('WAT', 7),
#  ('JER', 154),
#  ('YTH', 4),
#  ('YRT', 5),
#  ('KGL', 9),
#  ('LXA', 158),
#  ('BJM', 3),
#  ('TRU', 24),
#  ('AQP', 80),
#  ('CCP', 60),
#  ('IFN', 16),
#  ('BPX', 12),
#  ('TCQ', 14),
#  ('JNG', 26),
#  ('OZC', 21),
#  ('JZH', 13),
#  ('GYS', 9),
#  ('BCD', 109),
#  ('LUM', 49),
#  ('NAO', 31),
#  ('HIA', 49),
#  ('BBI', 118),
#  ('DAX', 30),
#  ('YDF', 10),
#  ('DNK', 37),
#  ('CGD', 10),
#  ('CIX', 28),
#  ('STW', 29),
#  ('ZOS', 7),
#  ('ILG', 8),
#  ('ARI', 41),
#  ('YUS', 4),
#  ('UKK', 16),
#  ('JXA', 13),
#  ('PEI', 11),
#  ('TCZ', 41),
#  ('GDZ', 5),
#  ('ERL', 7),
#  ('KHG', 5),
#  ('BBA', 26),
#  ('TOE', 6),
#  ('TPQ', 6),
#  ('IOS', 13),
#  ('LGP', 49),
#  ('DPL', 14),
#  ('DIG', 28),
#  ('GIB', 24),
#  ('NOP', 5),
#  ('LMM', 9),
#  ('BGA', 29),
#  ('LVI', 7),
#  ('LGQ', 1),
#  ('KGS', 5),
#  ('VCT', 2),
#  ('BDG', 2),
#  ('COE', 2),
#  ('JEF', 4),
#  ('BTP', 1),
#  ('LSY', 16),
#  ('JCI', 5),
#  ('MNM', 1),
#  ('PLD', 1),
#  ('JVL', 3),
#  ('SAC', 10),
#  ('LVK', 16),
#  ('PWK', 11),
#  ('AHN', 5),
#  ('MYL', 2),
#  ('MOD', 1),
#  ('LWM', 1),
#  ('CIU', 9),
#  ('RKD', 1),
#  ('HAD', 10),
#  ('FNL', 3),
#  ('ALO', 13),
#  ('AMW', 2),
#  ('CTH', 1),
#  ('LER', 10),
#  ('IAS', 38),
#  ('GYL', 4),
#  ('WWI', 1),
#  ('WLP', 13),
#  ('LAE', 8),
#  ('DAV', 9),
#  ('DCN', 5),
#  ('KNX', 18),
#  ('RAS', 6),
#  ('WWK', 1),
#  ('HDM', 2),
#  ('WMH', 1),
#  ('RMG', 1),
#  ('HOT', 1),
#  ('CKM', 1),
#  ('GCK', 22),
#  ('ORH', 14),
#  ('AOG', 12),
#  ('CNJ', 2),
#  ('HJJ', 4),
#  ('CKS', 4),
#  ('TTT', 1),
#  ('VAL', 1),
#  ('YSJ', 29),
#  ('FDE', 17),
#  ('RRS', 5),
#  ('HYS', 10),
#  ('MKG', 10),
#  ('VLD', 13),
#  ('ABY', 12),
#  ('RGS', 4),
#  ('MEI', 5),
#  ('SLM', 4),
#  ('OTH', 4),
#  ('RJL', 1),
#  ('ILE', 2),
#  ('IWD', 11),
#  ('IPL', 5),
#  ('ABX', 35),
#  ('DEC', 8),
#  ('BRL', 1),
#  ('PDT', 1),
#  ('VIS', 2),
#  ('RKP', 1),
#  ('GBD', 2),
#  ('TMW', 13),
#  ('DUJ', 2),
#  ('SHD', 1),
#  ('KUV', 12),
#  ('OUZ', 2),
#  ('TDD', 1),
#  ('ENW', 2),
#  ('GAO', 2),
#  ('PMV', 1),
#  ('UCT', 1),
#  ('TGC', 1),
#  ('HHR', 16),
#  ('LNA', 4),
#  ('CED', 3),
#  ('BHS', 8),
#  ('BHQ', 12),
#  ('YZZ', 1),
#  ('HMV', 2),
#  ('NRA', 8),
#  ('MOV', 12),
#  ('UDD', 4),
#  ('VEL', 3),
#  ('OXC', 1),
#  ('BBX', 1),
#  ('LRU', 1),
#  ('CXP', 1),
#  ('BHE', 2),
#  ('PPQ', 1),
#  ('HFS', 2),
#  ('YZD', 4),
#  ('ZAD', 8),
#  ('ALW', 5),
#  ('SJZ', 1),
#  ('IPT', 8),
#  ('BDB', 16),
#  ('POU', 1),
#  ('UVA', 3),
#  ('WDG', 2),
#  ('MYV', 2),
#  ('SIG', 1),
#  ('CFD', 1),
#  ('YQQ', 23),
#  ('XSD', 9),
#  ('TMR', 1),
#  ('UOX', 3),
#  ('GED', 1),
#  ('BVX', 1),
#  ('GWO', 1),
#  ('BKL', 2),
#  ('LAI', 13),
#  ('FSP', 7),
#  ('UVE', 10),
#  ('GIZ', 67),
#  ('VUP', 24),
#  ('HMB', 39),
#  ('HUI', 86),
#  ('CTM', 11),
#  ('RKT', 28),
#  ('RBR', 11),
#  ('NAW', 7),
#  ('EAM', 30),
#  ('RAE', 12),
#  ('LDS', 2),
#  ('SHW', 4),
#  ('ABT', 19),
#  ('LAQ', 22),
#  ('BHH', 13),
#  ('UIH', 27),
#  ('TZL', 12),
#  ('LRR', 6),
#  ('TAP', 3),
#  ('FYJ', 1),
#  ('MHC', 4),
#  ('AXM', 2),
#  ('KQT', 1),
#  ('CCK', 2),
#  ('MPN', 1),
#  ('GXF', 1),
#  ('TOB', 1),
#  ('BUY', 1),
#  ('MRH', 1),
#  ('GYY', 1),
#  ('WLW', 1),
#  ('BZO', 20),
#  ('AUO', 3),
#  ('CLW', 2),
#  ('ALM', 1),
#  ('PZB', 2),
#  ('UTN', 1),
#  ('OLP', 15),
#  ('GEV', 6),
#  ('ZBF', 7),
#  ('VDS', 10),
#  ('ART', 9),
#  ('SKN', 2),
#  ('SKE', 1),
#  ('YYE', 2),
#  ('GYI', 1),
#  ('NUQ', 1),
#  ('BIH', 1),
#  ('FMS', 1),
#  ('OME', 2),
#  ('RWI', 1),
#  ('DXR', 1),
#  ('TME', 1),
#  ('TDZ', 1),
#  ('ZYL', 10),
#  ('CHG', 7),
#  ('WNH', 10),
#  ('YIE', 7),
#  ('JOS', 5),
#  ('ABB', 1),
#  ('NOV', 3),
#  ('NER', 2),
#  ('SZA', 1),
#  ('PSS', 1),
#  ('LNJ', 1),
#  ('SVL', 1),
#  ('AJR', 9),
#  ('CZS', 1),
#  ('TJA', 14),
#  ('FBM', 1),
#  ('CIJ', 4),
#  ('OMO', 4),
#  ('MKW', 1),
#  ('VKG', 5),
#  ('VCS', 19),
#  ('PXU', 8),
#  ('MEE', 8),
#  ('JOK', 2),
#  ('VCL', 3),
#  ('PNL', 1),
#  ('TIR', 8),
#  ('VDH', 4),
#  ('GBB', 2),
#  ('MGQ', 1),
#  ('HOD', 2),
#  ('DLH', 86),
#  ('MEL', 2139),
#  ('IJK', 17),
#  ('ZRH', 2065),
#  ('PUQ', 62),
#  ('ACI', 24),
#  ('JAX', 603),
#  ('DAB', 178),
#  ('MKE', 685),
#  ('OGD', 5),
#  ('ORD', 7605),
#  ('PSP', 357),
#  ('MIA', 3276),
#  ('DAL', 1092),
#  ('PMF', 21),
#  ('FSC', 33),
#  ('SRQ', 193),
#  ('HWD', 10),
#  ('OAK', 1139),
#  ('MMH', 32),
#  ('GVA', 1545),
#  ('ICT', 244),
#  ('DSA', 120),
#  ('YUM', 79),
#  ('CFE', 48),
#  ('MAF', 167),
#  ('EWN', 53),
#  ('GRR', 296),
#  ('DLE', 15),
#  ('RST', 36),
#  ('RIC', 426),
#  ('SML', 2),
#  ('OAJ', 43),
#  ('CCF', 22),
#  ('JAN', 187),
#  ('AGF', 28),
#  ('CMF', 103),
#  ('MRS', 775),
#  ('BNE', 1838),
#  ('KLV', 8),
#  ('HUY', 82),
#  ('PVD', 308),
#  ('HYI', 10),
#  ('SMF', 854),
#  ('SNA', 905),
#  ('ELP', 304),
#  ('ACV', 45),
#  ('PAE', 91),
#  ('MSQ', 270),
#  ('MJZ', 4),
#  ('OVB', 252),
#  ('GJT', 76),
#  ('HOU', 839),
#  ('BCN', 2214),
#  ('CTA', 421),
#  ('VDB', 6),
#  ('NDB', 5),
#  ('OLA', 2),
#  ('YQT', 121),
#  ('KSU', 33),
#  ('GVL', 6),
#  ('KSC', 27),
#  ('GRO', 76),
#  ('NUE', 270),
#  ('BHX', 707),
#  ('BNK', 43),
#  ('TSV', 182),
#  ('WGA', 28),
#  ('WIN', 2),
#  ('CFN', 14),
#  ('IAD', 2063),
#  ('GFN', 7),
#  ('MQL', 29),
#  ('BOS', 2665),
#  ('HGD', 2),
#  ('GOT', 438),
#  ('ARN', 1469),
#  ('LDY', 27),
#  ('PNS', 177),
#  ('INV', 73),
#  ('CFS', 30),
#  ('KLU', 39),
#  ('TUF', 8),
#  ('KOK', 8),
#  ('MMX', 167),
#  ('BUD', 819),
#  ('DMD', 1),
#  ('VXO', 25),
#  ('TSR', 76),
#  ('PIK', 36),
#  ('BLE', 6),
#  ('PBI', 730),
#  ('SZZ', 32),
#  ('YVR', 1535),
#  ('RSW', 836),
#  ('TUS', 401),
#  ('VCP', 496),
#  ('CAE', 202),
#  ('PER', 1409),
#  ('RDU', 958),
#  ('KGI', 49),
#  ('BME', 69),
#  ('SAV', 309),
#  ('PHE', 93),
#  ('ALH', 29),
#  ('PNE', 7),
#  ('LVO', 10),
#  ('MXP', 1323),
#  ('PTK', 17),
#  ('TVI', 4),
#  ('APA', 36),
#  ('FDK', 7),
#  ('YYC', 2127),
#  ('DRW', 252),
#  ('BFI', 190),
#  ('DOL', 6),
#  ('OSR', 69),
#  ('AVL', 76),
#  ('JHW', 2),
#  ('DSM', 328),
#  ('MAD', 3022),
#  ('ETZ', 31),
#  ('ASE', 171),
#  ('CMH', 751),
#  ('FTY', 7),
#  ('SQL', 26),
#  ('OKC', 423),
#  ('MDT', 195),
#  ('HSV', 186),
#  ('BIM', 2),
#  ('RDG', 1),
#  ('GOA', 132),
#  ...]

# %% [markdown]
# Woah! This is a big list of results ! Maybe you would be interested only in the most frequented airports !?
# Let's sort this out!

# %%
counted_departure_sorted = counted_departure.sortBy(lambda x: x[1], ascending=False)
counted_departure_sorted.take(5)
# Out:
# [(None, 154461), ('ORD', 7605), ('ATL', 7442), ('DFW', 6614), ('LAX', 5752)]

# %% [markdown]
# *Nota*: There is a bunch of ways to compute the same thing ... We could have used functions like **keyBy, mapValues** ... refer to the [documentation](https://spark.apache.org/docs/latest/rdd-programming-guide.html) to have an overview !

# %% [markdown]
# ### Save our result to a text file locally
#
# This is an action that will trigger every transformations from the transformation plan of Spark!

# %%
# Add foundry stuff

#counted_departure_sorted.coalesce(1).saveAsTextFile("res.txt")
#saveAsHadoop ...

# %%
sc = spark.sparkContext
a = sc.parallelize([1,2,3])
b = a.map(lambda x : x**2)
c= b.filter(lambda x: x< 3)
print(c.toDebugString())
c.collect()
# Out:
# b'(2) PythonRDD[34] at RDD at PythonRDD.scala:55 []\n |  ParallelCollectionRDD[33] at parallelize at PythonRDD.scala:198 []'
# [1]

# %%
spark.stop()
